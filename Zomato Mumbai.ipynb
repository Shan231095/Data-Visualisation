# %% [markdown]
# ## Zomato Mumbai Data Analysis Project

# %% [markdown]
# ## 1.Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "svg"

# %%
#!pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.30.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\anaconda3\envs\aiml\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.8 MB 840.2 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/14.8 MB 1.1 MB/s eta 0:00:13
#    -- ------------------------------------- 1.0/14.8 MB 1.1 MB/s eta 0:00:13
#    ---- ----------------------------------- 1.6/14.8 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/14.8 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.1/14.8 MB 1.3 MB/s eta 0:00:10
#    ------- -------------------------------- 2.6/14.8 MB 1.4 MB/s eta 0:00:09
#    ------- -------------------------------- 2.9/14.8 MB 1.4 MB/s eta 0:00:09
#    -------- ------------------------------- 3.1/14.8 MB 1.4 MB/s eta 0:00:09
#    --------- ------------------------------ 3.4/14.8 MB 1.4 MB/s eta 0:00:09
#    --------- ------------------------------ 3.4/14.8 MB 1.4 MB/s eta 0:00:09
#    --------- ------------------------------ 3.7/14.8 MB 1.3 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.9/14.8 MB 1.3 MB/s eta 0:00:09
#    ----------- ---------------------------- 4.2/14.8 MB 1.3 MB/s eta 0:00:09
#    ------------ --------------------------- 4.5/14.8 MB 1.2 MB/s eta 0:00:09
#    ------------ --------------------------- 4.5/14.8 MB 1.2 MB/s eta 0:00:09
#    ------------ --------------------------- 4.7/14.8 MB 1.2 MB/s eta 0:00:09
#    ------------- -------------------------- 5.0/14.8 MB 1.2 MB/s eta 0:00:09
#    -------------- ------------------------- 5.2/14.8 MB 1.2 MB/s eta 0:00:09
#    -------------- ------------------------- 5.5/14.8 MB 1.2 MB/s eta 0:00:08
#    -------------- ------------------------- 5.5/14.8 MB 1.2 MB/s eta 0:00:08
#    --------------- ------------------------ 5.8/14.8 MB 1.1 MB/s eta 0:00:09
#    ---------------- ----------------------- 6.0/14.8 MB 1.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 6.3/14.8 MB 1.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 6.6/14.8 MB 1.2 MB/s eta 0:00:08
#    ------------------ --------------------- 6.8/14.8 MB 1.2 MB/s eta 0:00:07
#    ------------------- -------------------- 7.3/14.8 MB 1.2 MB/s eta 0:00:07
#    -------------------- ------------------- 7.6/14.8 MB 1.2 MB/s eta 0:00:06
#    --------------------- ------------------ 7.9/14.8 MB 1.2 MB/s eta 0:00:06
#    --------------------- ------------------ 8.1/14.8 MB 1.2 MB/s eta 0:00:06
#    ---------------------- ----------------- 8.4/14.8 MB 1.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 8.7/14.8 MB 1.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 8.7/14.8 MB 1.2 MB/s eta 0:00:06
#    ------------------------ --------------- 8.9/14.8 MB 1.2 MB/s eta 0:00:05
#    ------------------------ --------------- 8.9/14.8 MB 1.2 MB/s eta 0:00:05
#    ------------------------ --------------- 9.2/14.8 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 9.4/14.8 MB 1.1 MB/s eta 0:00:05
#    -------------------------- ------------- 9.7/14.8 MB 1.1 MB/s eta 0:00:05
#    -------------------------- ------------- 10.0/14.8 MB 1.1 MB/s eta 0:00:05
#    -------------------------- ------------- 10.0/14.8 MB 1.1 MB/s eta 0:00:05
#    --------------------------- ------------ 10.2/14.8 MB 1.1 MB/s eta 0:00:05
#    ----------------------------- ---------- 10.7/14.8 MB 1.1 MB/s eta 0:00:04
#    ------------------------------ --------- 11.3/14.8 MB 1.2 MB/s eta 0:00:04
#    ------------------------------ --------- 11.3/14.8 MB 1.2 MB/s eta 0:00:04
#    ------------------------------- -------- 11.5/14.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 12.1/14.8 MB 1.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 12.8/14.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 13.4/14.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 14.2/14.8 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.8 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 1.3 MB/s eta 0:00:00
# Downloading narwhals-1.30.0-py3-none-any.whl (313 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.30.0 plotly-6.0.0

# %% [markdown]
# ## 2. Importing the Dataset

# %%
raw_df=pd.read_csv("Zomato_Mumbai_Dataset.csv")

# %%
raw_df
# Out:
#       NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"|"URL"|"PAGE NO"|"CUSINE TYPE"|"TIMING"|"RATING_TYPE"|"RATING"|"VOTES"  \
# 0                          Hitchki|"1200"|"Modern Indian
# 1                           Baba Falooda|"400"|"Desserts
# 2                            Chin Chin Chu|"1800"|"Asian
# 3      Butterfly High|"1000"|"Modern Indian"|"Mumbai"...
# 4                         BKC  DIVE|"1200"|"North Indian
# ...                                                  ...
# 15076                 Hari Om Snack Bar|"350"|"Fast Food
# 15077                          PitaBurg|"400"|"Fast Food
# 15078                     Uncha Otlawala|"300"|"Desserts
# 15079                     Mandarin Panda|"400"|"Desserts
# 15080
#
#                                               Unnamed: 1  \
# 0                                           North Indian
# 1                                              Ice Cream
# 2      Chinese"|"Mumbai"|"Juhu"|"https://www.zomato.c...
# 3                                                    NaN
# 4                                                Chinese
# ...                                                  ...
# 15076                                       South Indian
# 15077  Lebanese"|"Mumbai"|"Lower Parel"|"https://www....
# 15078  Ice Cream"|"Mumbai"|"Kandivali West"|"https://...
# 15079                                            Chinese
# 15080                                                NaN
#
#                                               Unnamed: 2  \
# 0                                                Chinese
# 1      Beverages"|"Mumbai"|"Mahim"|"https://www.zomat...
# 2                                                    NaN
# 3                                                    NaN
# 4      Continental"|"Mumbai"|"Bandra Kurla Complex"|"...
# ...                                                  ...
# 15076  Chinese"|"Mumbai"|"Kandivali West"|"https://ww...
# 15077                                                Tue
# 15078                                                NaN
# 15079  Thai"|"Mumbai"|"Malad West"|"https://www.zomat...
# 15080                                                NaN
#
#                                     Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0                                        Momos    Biryani  Continental
# 1                                          NaN        NaN          NaN
# 2                                          NaN        NaN          NaN
# 3                                          NaN        NaN          NaN
# 4                                          NaN        NaN          NaN
# ...                                        ...        ...          ...
# 15076                                      NaN        NaN          NaN
# 15077                                      Wed        Thu         Sun)
# 15078                                      NaN        NaN          NaN
# 15079  7pm to 1am(Mon-Sun)"|"Good"|"3.7"|"121"        NaN          NaN
# 15080                                      NaN        NaN          NaN
#
#                               Unnamed: 6  \
# 0                               American
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 15076                                NaN
# 15077  11am to ..."|"Average"|"3.4"|"99"
# 15078                                NaN
# 15079                                NaN
# 15080                                NaN
#
#                                               Unnamed: 7 Unnamed: 8  \
# 0      Fast Food"|"Mumbai"|"First International Finan...        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 15076                                                NaN        NaN
# 15077                                                NaN        NaN
# 15078                                                NaN        NaN
# 15079                                                NaN        NaN
# 15080                                                NaN        NaN
#
#       Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0            NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...
# 15076        NaN         NaN         NaN         NaN
# 15077        NaN         NaN         NaN         NaN
# 15078        NaN         NaN         NaN         NaN
# 15079        NaN         NaN         NaN         NaN
# 15080        NaN         NaN         NaN         NaN
#
# [15081 rows x 13 columns]

# %%
raw_df.head()
# Out:
#   NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"|"URL"|"PAGE NO"|"CUSINE TYPE"|"TIMING"|"RATING_TYPE"|"RATING"|"VOTES"  \
# 0                      Hitchki|"1200"|"Modern Indian
# 1                       Baba Falooda|"400"|"Desserts
# 2                        Chin Chin Chu|"1800"|"Asian
# 3  Butterfly High|"1000"|"Modern Indian"|"Mumbai"...
# 4                     BKC  DIVE|"1200"|"North Indian
#
#                                           Unnamed: 1  \
# 0                                       North Indian
# 1                                          Ice Cream
# 2  Chinese"|"Mumbai"|"Juhu"|"https://www.zomato.c...
# 3                                                NaN
# 4                                            Chinese
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                            Chinese      Momos    Biryani
# 1  Beverages"|"Mumbai"|"Mahim"|"https://www.zomat...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  Continental"|"Mumbai"|"Bandra Kurla Complex"|"...        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6                                         Unnamed: 7  \
# 0  Continental   American  Fast Food"|"Mumbai"|"First International Finan...
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN

# %% [markdown]
# ## 3.Getting Basic Information about the Dataset

# %%
raw_df.columns
# Out:
# Index(['NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"|"URL"|"PAGE NO"|"CUSINE TYPE"|"TIMING"|"RATING_TYPE"|"RATING"|"VOTES"',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
raw_df.shape
# Out:
# (15081, 13)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 13 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"|"URL"|"PAGE NO"|"CUSINE TYPE"|"TIMING"|"RATING_TYPE"|"RATING"|"VOTES"  15081 non-null  object
#  1   Unnamed: 1                                                                                                            11369 non-null  object
#  2   Unnamed: 2                                                                                                            7045 non-null   object
#  3   Unnamed: 3                                                                                                            3766 non-null   object
#  4   Unnamed: 4                                                                                                            1724 non-null   object
#  5   Unnamed: 5                                                                                                            797 non-null    object
#  6   Unnamed: 6                                                                                                            429 non-null    object
#  7   Unnamed: 7                                                                                                            222 non-null    object
#  8   Unnamed: 8                                                                                                            92 non-null     object
#  9   Unnamed: 9                                                                                                            38 non-null     object
#  10  Unnamed: 10                                                                                                           18 non-null     object
#  11  Unnamed: 11                                                                                                           10 non-null     object
#  12  Unnamed: 12                                                                                                           3 non-null      object
# dtypes: object(13)
# memory usage: 1.5+ MB

# %%
raw_df.describe()
# Out:
#        NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"|"URL"|"PAGE NO"|"CUSINE TYPE"|"TIMING"|"RATING_TYPE"|"RATING"|"VOTES"  \
# count                                               15081
# unique                                              13852
# top     NAME|"PRICE"|"CUSINE_CATEGORY"|"CITY"|"REGION"...
# freq                                                  942
#
#        Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# count       11369       7045       3766       1724        797        429
# unique       5563       4190       2558       1189        490        269
# top       Chinese    Chinese  Fast Food        Wed        Sat        Sat
# freq         1444        482        108         57         46         30
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# count         222         92         38          18          10
# unique        157         63         26          11           9
# top          Sun)       Sun)        Sat        Sun)        Sun)
# freq           20         11          6           7           2
#
#                              Unnamed: 12
# count                                  3
# unique                                 3
# top     630pm to ..."|"Good"|"3.9"|"369"
# freq                                   1

# %% [markdown]
# # 4. Cleaning the Dataset
# ## a.Removing the redundunt rows of data

# %%
#checking redundunt rows of data

wrong_data = raw_df['PAGE NO']=='PAGE NO'
raw_df[wrong_data]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda3\envs\aiml\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PAGE NO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 #checking redundunt rows of data
# ----> 3 wrong_data = raw_df['PAGE NO']=='PAGE NO'
#       4 raw_df[wrong_data]
#
# File C:\Anaconda3\envs\aiml\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File C:\Anaconda3\envs\aiml\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PAGE NO'
